# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Shrinil\Desktop\GPS FOLDER\arcserve\Python Stuff\data\StockNewsHeadline.csv",encoding='ISO-8859-1')

# %%
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
train=df[df['Date']<'201501010']
test=df[df['Date']>'20141231']

# %%
train.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
test.head()
# Out:
#             Date  Label                                               Top1  \
# 3723  2015-01-02      1  Most cases of cancer are the result of sheer b...
# 3724  2015-01-05      0  Moscow-&gt;Beijing high speed train will reduc...
# 3725  2015-01-06      0                    US oil falls below $50 a barrel
# 3726  2015-01-07      1                'Shots fired' at French magazine HQ
# 3727  2015-01-08      1  New Charlie Hebdo issue to come out next week:...
#
#                                                    Top2  \
# 3723  Iran dismissed United States efforts to fight ...
# 3724  Two ancient tombs were discovered in Egypt on ...
# 3725  Toyota gives away 5,680 fuel cell patents to b...
# 3726    90% of Bibi Netanyahus Campaign Funds From U.S.
# 3727  Ahmed Merabet, Cop Killed In Paris Attacks, Wa...
#
#                                                    Top3  \
# 3723  Poll: One in 8 Germans would join anti-Muslim ...
# 3724  China complains to Pyongyang after N Korean so...
# ...

# %%
#removing everything apart from a-z and A-Z.
data=train.iloc[:,2:27]
data.replace('[^a-zA-Z]',' ',regex=True,inplace=True)

# %%
data
# Out:
#                                                    Top1  \
# 0     A  hindrance to operations   extracts from the...
# 1                                             Scorecard
# 2                     Coventry caught on counter by Flo
# 3                         Pilgrim knows how to progress
# 4                                  Hitches and Horlocks
# ...                                                 ...
# 3970  Brazil declares emergency after       babies a...
# 3971  Germany recruits       teachers to teach Germa...
# 3972  Pentagon thwarts Obama s effort to close Guant...
# 3973  Tech companies face criminal charges if they n...
# 3974  Microsoft Corp said on Wednesday it will begin...
#
#                                                    Top2  \
# 0                                             Scorecard
# 1                                   The best lake scene
# 2                    United s rivals on the road to Rio
# 3                                   Thatcher facing ban
# ...

# %%
list1=[i for i in range(25)] #chaing the cloumns from strings to numbers.
new_index=[str(i) for i in list1]
data.columns=new_index
data.head()
# Out:
#                                                    0  \
# 0  A  hindrance to operations   extracts from the...
# 1                                          Scorecard
# 2                  Coventry caught on counter by Flo
# 3                      Pilgrim knows how to progress
# 4                               Hitches and Horlocks
#
#                                     1  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United s rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                                2  \
# 0                Hughes  instant hit buoys Blues
# 1                  Leader  German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# 4                        Breast cancer screening
#
#                                                3  \
# 0       Jack gets his skates on at ice cold Alex
# ...

# %%
for i in new_index:
    data[i]=data[i].str.lower() #converting everything into lowercase.
data.head(2)
# Out:
#                                                    0                    1  \
# 0  a  hindrance to operations   extracts from the...            scorecard
# 1                                          scorecard  the best lake scene
#
#                                  2                                         3  \
# 0  hughes  instant hit buoys blues  jack gets his skates on at ice cold alex
# 1    leader  german sleaze inquiry                             cheerio  boyo
#
#                                         4  \
# 0  chaos as maracana builds up for united
# 1                the main recommendations
#
#                                                    5  \
# 0  depleted leicester prevail as elliott spoils e...
# 1                             has cubie killed fees
#
#                                   6                                  7  \
# 0  hungry spurs sense rich pickings  gunners so wide of an easy target
# ...

# %%
#ive to make the all headlines in one row as one paragraph.
headlines=[]
for row in range(0,len(data.index)):
    headlines.append(' '.join(str(x) for x in data.iloc[row,0:25]))

# %%
headlines[2]
# Out:
# 'coventry caught on counter by flo united s rivals on the road to rio thatcher issues defence before trial by video police help smith lay down the law at everton tale of trautmann bears two more retellings england on the rack pakistan retaliate with call for video of walsh cullinan continues his cape monopoly mcgrath puts india out of their misery blair witch bandwagon rolls on pele turns up heat on ferguson party divided over kohl slush fund scandal manchester united  england  women in record south pole walk vasco da gama  brazil  south melbourne  australia  necaxa  mexico  real madrid  spain  raja casablanca  morocco  corinthians  brazil  tony s pet project al nassr  saudi arabia  ideal holmes show pinochet leaves hospital after tests useful links'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier

# %%
tf_idf= TfidfVectorizer(stop_words='english', max_features=5000)

# %%
#implement tf-idf
traindata=tf_idf.fit_transform(headlines)

# %%
##doing modifications for test dataset.
test_transform=[]
for row in range(0,len(test.index)):
    test_transform.append(' '.join(str(y) for y in test.iloc[row,2:27]))

# %%
test.head()
# Out:
#             Date  Label                                               Top1  \
# 3723  2015-01-02      1  Most cases of cancer are the result of sheer b...
# 3724  2015-01-05      0  Moscow-&gt;Beijing high speed train will reduc...
# 3725  2015-01-06      0                    US oil falls below $50 a barrel
# 3726  2015-01-07      1                'Shots fired' at French magazine HQ
# 3727  2015-01-08      1  New Charlie Hebdo issue to come out next week:...
#
#                                                    Top2  \
# 3723  Iran dismissed United States efforts to fight ...
# 3724  Two ancient tombs were discovered in Egypt on ...
# 3725  Toyota gives away 5,680 fuel cell patents to b...
# 3726    90% of Bibi Netanyahus Campaign Funds From U.S.
# 3727  Ahmed Merabet, Cop Killed In Paris Attacks, Wa...
#
#                                                    Top3  \
# 3723  Poll: One in 8 Germans would join anti-Muslim ...
# 3724  China complains to Pyongyang after N Korean so...
# ...

# %%
testdata=tf_idf.transform(test_transform)

# %%
#creating the model.
model=RandomForestClassifier(n_estimators=300,criterion='entropy')
model.fit(traindata,train['Label'])
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=300)

# %%
predicts=model.predict(testdata)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
matrix=confusion_matrix(test['Label'],predicts)
print(matrix)
# Out:
# [[147  39]
#  [ 18 174]]

# %%
score=accuracy_score(test['Label'],predicts)
print(score)
# Out:
# 0.8492063492063492
